# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('pstw_dataset.xlsx')
df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1964 entries, 0 to 1963
# Data columns (total 56 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   PSTW ID                                                                               1964 non-null   object
#  1   Name                                                                                  1964 non-null   object
#  2   Website                                                                               1964 non-null   object
#  3   Description                                                                           1964 non-null   object
#  4   Geographical extent                                                                   1964 non-null   object
# ...

# %%
print(df['Primary Technology'].unique())
print(df['Secondary Technology'].unique())

df_ai = df[df['Primary Technology'] == 'Artificial Intelligence']
# Out:
# ['Artificial Intelligence' 'Blockchain' 'AR/VR' 'Artificial intelligence'
#  'Quantum computing' 'Virtual Worlds' 'Digital Twins' 'Quantum Computing'
#  'Other' '5G (Edge Computing)']
# [nan 'Digital Twins' '5G (Edge Computing)' 'Quantum Computing'
#  'Artificial Intelligence' 'AR/VR' 'Virtual Worlds'
#  'Open source, Low-code platform']

# %%
print(df['Geographical coverage (country)'].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Czechia' 'Denmark'
#  'Estonia' 'Finland' 'France' 'Poland' 'Germany' 'Ireland' 'Italy'
#  'Latvia' 'Netherlands' 'Spain' 'Norway' 'Portugal' 'Romania' 'Slovakia'
#  'Slovenia' 'United Kingdom' 'Sweden' 'Switzerland' 'Greece' 'Hungary'
#  'Luxembourg' 'European Union' 'Ukraine' 'Moldova' 'Malta' 'Andorra'
#  'San Marino' 'Lithuania' 'Serbia' 'North Macedonia' 'Albania' 'Georgia'
#  'Iceland' 'Türkiye' 'Denmark ' 'Vatican City' 'Bosnia and Herzegovina'
#  'Poland ']

# %%
print(df[' Status'].unique())

print(df['Improved Public Service'])
# Out:
# ['Not in use' 'Implemented' 'Pilot' 'Planned' 'In development'
#  'Pilot phase']
# 0         x
# 1         x
# 2         x
# 3         x
# 4         x
#        ...
# 1959      x
# 1960      x
# 1961      x
# 1962    NaN
# 1963      x
# Name: Improved Public Service, Length: 1964, dtype: object

# %%
# from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

mapping = {
  'Pilot': 'Pilot',
  'Pilot phase': 'Pilot',
  'Planned': 'Planned/In developlment',
  'Implemented': 'Implemented',
  'Not in use': 'Not in use'
}

df['Status_grouped'] = df[' Status'].map(mapping)

le = LabelEncoder()

y_classes = le.fit_transform(df['Status_grouped'])

print(le.classes_)
print(df[[' Status', 'Status_grouped']])

# X = df_encoded.drop("left", axis=1)
X = df.drop([' Status', 'Status_grouped'], axis=1)

y = y_classes

X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2)
# Out:
# ['Implemented' 'Not in use' 'Pilot' 'Planned/In developlment' nan]
#            Status Status_grouped
# 0      Not in use     Not in use
# 1     Implemented    Implemented
# 2     Implemented    Implemented
# 3     Implemented    Implemented
# 4     Implemented    Implemented
# ...           ...            ...
# 1959  Implemented    Implemented
# 1960  Implemented    Implemented
# 1961  Implemented    Implemented
# 1962  Implemented    Implemented
# 1963  Implemented    Implemented
#
# [1964 rows x 2 columns]

# %%
# import matplotlib.pyplot as plt
# from sklearn.ensemble import RandomForestClassifier


# rm_forest_model = RandomForestClassifier(random_state=42)
# rm_forest_model.fit(X_train, y_train)

# importances = pd.Series(rm_forest_model.feature_importances_).sort_values(ascending=False)

# print(importances)

# importances.plot(kind='bar')
# plt.title('Feature Importances')
# plt.xlabel('Features')
# plt.ylabel('Importance')

# plt.tight_layout()

# plt.show()

# %%
print(df['Funding source'])
# Out:
# 0       National-funded project
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#                  ...
# 1959                        NaN
# 1960                        NaN
# 1961                        NaN
# 1962                        NaN
# 1963                        NaN
# Name: Funding source, Length: 1964, dtype: object

# %% [markdown]
# # Datasetet #
# Datasettet innehåller information om AI/ MI projekt i EU med en stor mängd information. Alla projekt är inom den offentliga sektorn.
#
# #### Viktiga kolumner ####
# - Geographical extent - Beskriver vilka områden som projektet täcker. {National 47%, Local, 32%, Regional, 11%, Other 10%}
# - Responsible organisation category - Beskriver vilken sektor som organisationen bakom projektet tillhör. Kan vara en viktig X variabel beroende på vem som står bakom ett framtida projekt. {Central-Government 35%, Local Government32%, Academic-Research12%, Other21%}
# - Functions of government - Statliga tjänster. {General public services30%, Economic affairs18%, Public order and safety15%, Other37%}
# -
# #### Potentiella Y-variabler ####
# Status tillsammans med Start Year - End Year
# - Beräkna vilka projekt lyckas (Implemented, in development), behöver tolka pilot om det räknas som att ett projekt lyckats
# - Går att Beräkna hur lång tid det tar för ett projekt att avslutas
#
# ### Kolumner att kolla in ###
# Geographical extent och coverage - Täcker de samma data och är de endast relevanta för projekt som täcker flera nationer
#
# NUTS 2021 - Kan vara ett bra sätt att hålla kolla på länderna ifråga
#
# Process type - Syftet med projektet ex. analys, enforcement
#
# Application type - Beskriver applicationen ex. data sharing
#
# Interaction
#
# AI Classification I
#
# AI Classification Subdomain (II) (main)
#
# AI keywords (71% missing values, värt att kolla hur de ligger till jämfört med projekt som är i Produktion eller implementerade)
#
# Collaboration type(64% missing values, samma som tidigare och kan vara en viktig faktor beroende på vad det är för organisation som går in i ett projekt)
#
# Funding source
#
# Cost reduction (sketchy)
#
#
#
# ### Kolumner som ska droppas ###
# PSTW ID
#
# Name
#
# Website
#
# Description
#
# GovTech
#
# GovTech Initativ
#
# Cross Border (Ojämn statistik, No 85%)
#
# Cross Sector (Ojämn statistik, No 87%)
#
# Secondary Technology (99% missing value)
#
# Start year - End year (Kan vara viktigt beroende på vem som står bakom projektet (lokalt, nationellt internationellt pga. politik))
#
# Source
#
# AI Classification Subdomain (II) (Other I)
#
# AI Classification Subdomain (II) (Other II)
#
# AI Classification Subdomain (II) (Other III)
#
# Procurement (EU Model Contractual AI)
#
# Company name or GovTech ID
#
# GovTech Initiative + ID
#
# Open components in input
#
# Improved public control and influence on government actions and policies
#
# Open components in output
#
# Stories link
#
# Date updated
#
# Better collaboration and better communication
#
# Reduced or eliminated the risk of corruption and abuse of the law by public servants
#
# Enabled greater fairness, honesty, equality
#
#
#
# Procurement (EU Model Contractual AI)
#  4   Geographical extent                                                                   1964 non-null   object
#  5   Geographical coverage (country)                                                       1964 non-null   object
#  7   Responsible organisation                                                              1964 non-null   object
#  8   Responsible organisation category                                                     1964 non-null   object
#  9   Functions of Government (COFOG level I)                                               1964 non-null   object
#  10  Functions of Government (COFOG level II)                                              1964 non-null   object
#  11   Status                                                                               1964 non-null   object
#  14  Process type                                                                          1964 non-null   object
#  15  Application type                                                                      1964 non-null   object
#  16  Cross Border                                                                          1963 non-null   object
#  17  Cross Sector                                                                          1963 non-null   object
#  20  Interaction                                                                           1964 non-null   object
#  21  Improved Public Service                                                               1046 non-null   object
#  22  Personalized Services                                                                 366 non-null    object
#  23  Public (citizen)-centered services                                                    639 non-null    object
#  24  Increase quality of PSI and services                                                  594 non-null    object
#  25  More responsive, efficient, and cost-effective public services                        756 non-null    object
#  26  New services or channels                                                              622 non-null    object
#  27  Improved Administrative Efficiency                                                    915 non-null    object
#  28  Cost-reduction                                                                        165 non-null    object
#  29  Responsiveness of government operation                                                397 non-null    object
#  30  Improved management of public resources                                               386 non-null    object
#  31  Increased quality of processes and systems                                            732 non-null    object
#  35  Open government capabilities                                                          265 non-null    object
#  36  Increased transparency of public sector operations                                    248 non-null    object
#  39  Source                                                                                1950 non-null   object
#  40  AI Classification (I)                                                                 1585 non-null   object
#  41  AI Classification Subdomain (II) (main)                                               1585 non-null   object
#  42  AI Classification Subdomain (II) (Other I)                                            1191 non-null   object
#  45  AI Keywords                                                                           571 non-null    object
#  46  Collaboration type                                                                    704 non-null    object
#  48  Funding source                                                                        991 non-null    object
